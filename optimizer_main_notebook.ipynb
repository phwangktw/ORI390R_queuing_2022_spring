# %% [markdown]
# <a href="https://colab.research.google.com/github/phwangktw/ORI390R_queuing_2022_spring/blob/main/optimizer_main_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ciw
# Out:
# Requirement already satisfied: ciw in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.7/dist-packages (from ciw) (2.6.3)
# Requirement already satisfied: tqdm==4.14.0 in /usr/local/lib/python3.7/dist-packages (from ciw) (4.14.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from ciw) (6.0)

# %%
pip install pygad
# Out:
# Requirement already satisfied: pygad in /usr/local/lib/python3.7/dist-packages (2.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from pygad) (3.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pygad) (1.21.6)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (4.33.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pygad) (3.0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->pygad) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib->pygad) (1.15.0)

# %%
# !pip install matplotlib==3.5.1
# Out:
# Requirement already satisfied: matplotlib==3.5.1 in /usr/local/lib/python3.7/dist-packages (3.5.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (1.21.6)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1) (3.0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib==3.5.1) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib==3.5.1) (1.15.0)

# %%
import pygad
import numpy

import simulator as sm

# Set cost for deposition to 2, polishing to 1, photo to 8, etch to 5

# function_inputs = [2,1,8,5,2,2,1,8,5,2,1,8,5] #The wieght for each machine type
# desired_output = 500 #The target for obj. function

def fitness_func(solution, solution_idx): #Obj. function, can be modified
    print('Current combination:')
    print(solution)
    output = sm.cost_evaluation(solution)
    print('Cost ='+str(-1*output))
    fitness = 1.0 / output
    
    return fitness

ga_instance = pygad.GA(num_generations=20, #Number of iteration
                       num_parents_mating=4, #Number of parent genes
                       sol_per_pop=50, #Number of offspring per iteration
                       num_genes=13, #Number of genes
                       fitness_func=fitness_func,
                       mutation_type="adaptive", #Increasing mutation to change values
                       mutation_probability=[0.6, 0.2], 

                       init_range_low=1,
                       init_range_high=10,
                       gene_space = [range(1,8),range(1,10),range(6,16),range(3,13),
                                     range(1,10),range(1,8),range(1,11),range(2,12),
                                     range(2,12),range(1,8),range(1,10),range(2,12),
                                     range(3,13)],
                      
                       gene_type=int)

#print(ga_instance.initial_population)
#print(ga_instance.initial_population.shape)
ga_instance.run()
ga_instance.plot_result()
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
# Out:
# Current combination:
# [ 5  5  8 12  6  4 10  9  6  3  2  3  5]
# Cost =-565.5264705882353
# Current combination:
# [4 8 9 5 7 6 9 8 7 4 4 4 6]
# Cost =-472.8505294117647
# Current combination:
# [ 1  9  7 12  1  6  1  9  7  6  6  7  3]
# Cost =-799.1268823529413
# Current combination:
# [ 6  9 12  4  8  1  1  9  8  4  8  3  8]
# Cost =-707.7048823529411
# Current combination:
# [ 7  1  6  3  6  1  9  8  3  6  7 11  9]
# Cost =-680.7508823529413
# Current combination:
# [ 6  9 12 10  4  1  3  6  2  2  9  9 11]
# Cost =-664.8247647058823
# Current combination:
# [ 2  9 11 12  6  2  8  8 11  6  9  7  7]
# Cost =-469.58605882352947
# Current combination:
# [ 4  4 15  4  1  7  7  7  5  1  9  5 12]
# Cost =-868.6877058823529
# Current combination:
# [ 5  9 12 11  1  5  2  5 10  1  5  2 12]
# Cost =-839.2105882352939
# Current combination:
# [ 5  9 11  5  9  5  6  5  4  1  8  8  3]
# Cost =-539.335705882353
# Current combination:
# [ 3  2 15  5  1  4  6  6 11  6  6  5  7]
# Cost =-853.0904117647058
# Current combination:
# [ 2  7  9 12  2  1  3  8  8  2  4  4  7]
# Cost =-625.6169411764706
# Current combination:
# [ 6  3 11  8  7  6  3  2  8  5  2  2  9]
# Cost =-610.4686470588235
# Current combination:
# [ 6  7 10  3  6  3  3  5  8  1  7  4  5]
# Cost =-526.4502352941176
# Current combination:
# [ 5  7  6  9  7  2  7 11  4  5  1  3  4]
# Cost =-596.775
# Current combination:
# [ 1  1  9 10  2  3  4  8 10  5  5  2  4]
# Cost =-693.4735882352941
# Current combination:
# [ 4  3  8  3  3  6  3  7 11  4  7  4  8]
# Cost =-499.84023529411763
# Current combination:
# [ 4  7 14  7  6  5  1 10  5  3  8  9  5]
# Cost =-730.9279411764707
# Current combination:
# [ 3  3 11  3  9  2  5  4  2  1  4  6 11]
# Cost =-592.4182352941177
# Current combination:
# [ 3  2 10  3  2  5  8  4 10  5  8  8  7]
# Cost =-606.6187058823529
# Current combination:
# [ 3  2 13  3  5  4  4 10 11  6  4  5  8]
# Cost =-522.6113529411765
# Current combination:
# [ 1  3 13  4  2  5  5 11 11  1  6  7  3]
# Cost =-710.8259411764706
# Current combination:
# [ 5  2  7  3  6  7  3  6  3  6  5  8 11]
# Cost =-528.7694117647059
# Current combination:
# [ 2  6 15  4  5  6 10  9  4  3  2 10  7]
# Cost =-527.362294117647
# Current combination:
# [ 1  3 12  9  2  7  9 10 11  1  5  3  4]
# Cost =-674.679
# Current combination:
# [ 3  5 12  8  5  4  6  6  5  1  3  9 10]
# Cost =-503.2367647058823
# Current combination:
# [ 6  6  7 12  9  7  2  6  7  4  7 11  4]
# Cost =-627.0728823529412
# Current combination:
# [ 3  6  6 12  8  5  1  6 10  5  6  4  5]
# Cost =-646.3239411764705
# Current combination:
# [ 4  2 15  4  1  2 10  6  5  1  6  5  7]
# Cost =-825.8247647058822
# Current combination:
# [ 5  4  7 10  8  2  3  4 10  2  7  4 11]
# Cost =-472.3662352941177
# Current combination:
# [ 2  5  9 11  9  6  1  7  4  4  2  5 10]
# Cost =-642.2887647058824
# Current combination:
# [ 2  2 12  4  2  3  5  8  7  5  8  6  6]
# Cost =-579.6820588235294
# Current combination:
# [ 2  4 10  8  2  4  2  5  4  7  2 11  9]
# Cost =-662.5286470588235
# Current combination:
# [6 5 9 8 2 1 1 6 7 7 8 3 9]
# Cost =-686.9893529411764
# Current combination:
# [ 7  5 13 12  6  7  3  3  7  6  8  7  3]
# Cost =-621.3441176470589
# Current combination:
# [ 6  9 14  7  8  1  8  2  9  1  9  5  4]
# Cost =-647.7141764705882
# Current combination:
# [ 2  9 11  8  8  6 10  3 10  6  2  4  7]
# Cost =-508.722
# Current combination:
# [ 1  4 10  9  4  3  2 11  8  5  4  4  6]
# Cost =-644.6708823529411
# Current combination:
# [ 2  2 10  6  8  6  3 10  8  6  6  3  6]
# Cost =-568.7307647058824
# Current combination:
# [ 5  3 11 10  2  7  6  3  2  3  8  8  4]
# Cost =-607.6674705882352
# Current combination:
# [ 7  6 14  7  1  1 10  3  3  2  7  8  5]
# Cost =-877.261588235294
# Current combination:
# [ 4  7  9 10  6  6  3  2  3  5  9 11  4]
# Cost =-593.5964117647059
# Current combination:
# [3 7 6 6 7 4 8 3 6 7 5 4 5]
# Cost =-427.84152941176467
# Current combination:
# [ 2  9  7  7  1  2  4  2  3  5  8 11 12]
# Cost =-811.6125294117647
# Current combination:
# [ 3  5 10  7  2  7  6  9 11  4  1  7  4]
# Cost =-701.6458823529412
# Current combination:
# [ 7  7 11  8  7  4  1  2  7  4  4  4  3]
# Cost =-634.7853529411765
# Current combination:
# [ 2  4 11  9  9  5  8  9  2  3  4  6  6]
# Cost =-587.0014705882353
# Current combination:
# [ 7  6 15  3  6  2 10  9  3  6  2  3 12]
# Cost =-590.752705882353
# Current combination:
# [ 4  7 10 10  3  7  6 11 11  1  5  3 12]
# Cost =-592.1967647058823
# Current combination:
# [ 1  1 12  8  6  3  8  6  2  6  2  9  4]
# Cost =-738.593294117647
# Current combination:
# [ 3  7  6  6  7  2  8  8 11  6  9  7  7]
# Cost =-395.10835294117646
# Current combination:
# [ 2  9 11 10  8  2  3  4 10  2  7  4 11]
# Cost =-513.4030588235295
# Current combination:
# [ 5  4  7 10  7  6  9  8  7  4  4  4  6]
# Cost =-441.0260588235294
# Current combination:
# [4 8 6 6 7 4 8 3 6 7 5 4 5]
# Cost =-420.6145294117647
# Current combination:
# [ 3  7 11 12  6  2  8  8 11  6  9  7  7]
# Cost =-473.4764705882353
# Current combination:
# [ 2  9 11 12  6  2  3  4 10  2  7  4 11]
# Cost =-516.3685294117647
# Current combination:
# [ 5  4  7 10  8  2  3  4  7  4  4  4  6]
# Cost =-465.0133529411765
# Current combination:
# [4 7 6 6 7 4 8 3 6 7 5 4 5]
# Cost =-417.5642352941176
# Current combination:
# [ 3  7 11 12  6  2  8  8 11  6  9  7  7]
# Cost =-473.4764705882353
# Current combination:
# [ 2  9 11 12  6  2  8  8 11  2  7  4 11]
# Cost =-539.5158235294118
# Current combination:
# [ 5  4  7 10  8  2  3  4 10  2  7  4  6]
# Cost =-470.98888235294123
# Current combination:
# [4 8 9 5 7 6 9 8 7 7 5 4 5]
# Cost =-465.4601764705882
# Current combination:
# [ 3  7  6  6  7  4  8  3 11  6  9  7  7]
# Cost =-454.5044705882352
# Current combination:
# [ 2  9 11 12  6  2  3  4 10  2  7  4 11]
# Cost =-516.3685294117647
# Current combination:
# [ 5  4  7 10  8  2  9  8  7  4  4  4  6]
# Cost =-444.61676470588236
# Current combination:
# [4 8 9 5 7 4 8 3 6 7 5 4 5]
# Cost =-447.45682352941174
# Current combination:
# [3 7 6 6 7 4 8 3 6 6 9 7 7]
# Cost =-438.987
# Current combination:
# [ 5  4  7 10  8  2  3  4 10  2  7  4 11]
# Cost =-472.3662352941177
# Current combination:
# [ 5  4  7 10  8  2  3  4  7  4  4  4  6]
# Cost =-465.0133529411765
# Current combination:
# [4 8 9 5 7 6 9 8 7 4 4 4 5]
# Cost =-470.7478235294118
# Current combination:
# [3 7 6 6 7 4 8 3 6 7 5 7 7]
# Cost =-432.1724705882352
# Current combination:
# [ 2  9 11 12  8  2  3  4 10  2  7  4 11]
# Cost =-521.3678823529413
# Current combination:
# [ 5  4  7 10  8  2  3  4  7  4  4  4  6]
# Cost =-465.0133529411765
# Current combination:
# [4 8 9 5 7 6 9 8 7 4 4 4 5]
# Cost =-470.7478235294118
# Current combination:
# [ 3  7  6  6  7  4  8  8 11  6  9  7  7]
# Cost =-392.48199999999997
# Current combination:
# [ 2  9 11 12  6  2  8  8 11  6  9  4 11]
# Cost =-532.7764117647059
# Current combination:
# [ 5  4  7 10  7  6  9  8  7  4  4  4  6]
# Cost =-441.0260588235294
# Current combination:
# [4 8 6 6 7 4 8 3 6 7 5 4 5]
# Cost =-420.6145294117647
# Current combination:
# [3 7 6 6 7 4 8 3 6 7 5 4 7]
# Cost =-415.2308823529411
# Current combination:
# [ 2  9 11 12  8  2  3  4 10  2  7  4 11]
# Cost =-521.3678823529413
# Current combination:
# [ 5  4  7 10  8  2  3  4 10  2  4  4  6]
# Cost =-448.1381764705883
# Current combination:
# [4 8 9 5 7 6 9 8 7 4 4 4 5]
# Cost =-470.7478235294118
# Current combination:
# [ 2  9 11 12  6  2  8  8 11  6  9  7  7]
# Cost =-469.58605882352947
# Current combination:
# [ 2  9 11 12  6  2  8  8 11  6  9  4 11]
# Cost =-532.7764117647059
# Current combination:
# [4 8 9 5 7 6 9 8 7 4 4 4 6]
# Cost =-472.8505294117647
# Current combination:
# [4 8 6 6 7 4 8 3 6 7 5 4 5]
# Cost =-420.6145294117647
# Current combination:
# [ 3  7  6  6  7  2  8  8 11  6  9  7  7]
# Cost =-395.10835294117646
# Current combination:
# [ 2  9 11 12  6  2  3  4 10  2  7  4 11]
# Cost =-516.3685294117647
# Current combination:
# [ 5  4  7 10  7  6  9  8  7  4  4  4  6]
# Cost =-441.0260588235294
# Current combination:
# [4 8 9 6 7 4 8 3 6 7 5 4 5]
# Cost =-443.26699999999994
# Current combination:
# [ 3  7  6  6  7  4  8  8 11  6  9  7  7]
# Cost =-392.48199999999997
# Current combination:
# [ 2  9 11 12  8  2  3  4 10  2  7  4 11]
# Cost =-521.3678823529413
# Current combination:
# [5 4 7 5 7 6 9 8 7 4 4 4 6]
# Cost =-470.974
# Current combination:
# [4 8 9 5 7 6 8 3 6 7 5 4 5]
# Cost =-445.0519999999999
# Current combination:
# [ 3  7  6  6  7  2  8  8 11  6  9  7  7]
# Cost =-395.10835294117646
# Current combination:
# [ 2  9 11 12  6  2  8  8 11  6  9  7 11]
# Cost =-476.69788235294124
# Current combination:
# [ 6  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-399.653294117647
# Current combination:
# [ 2  9  7  8  6  5  3  7 10  2  7 11 11]
# Cost =-519.4865882352941
# Current combination:
# [ 6  4  7  7  7  6 10  8 10  4  4  4  6]
# Cost =-467.7182941176471
# Current combination:
# [4 8 6 6 1 5 8 4 6 7 5 4 5]
# Cost =-768.5851764705881
# Current combination:
# [ 3  6 13  5  6  4  8  4  6  1  9  7  7]
# Cost =-526.4165882352941
# Current combination:
# [ 5  4  6 11  7  7 10  9  9  6  1  5 11]
# Cost =-672.761294117647
# Current combination:
# [ 3  4 13 12  8  2  1  4  3  4  9  4  5]
# Cost =-666.6409411764706
# Current combination:
# [1 7 6 6 7 1 8 3 6 7 5 4 5]
# Cost =-579.5231176470588
# Current combination:
# [ 7  5 11  4  5  2  3  3 11  4  9  7  4]
# Cost =-538.6052352941176
# Current combination:
# [ 2  9 11  7  8  3  8  8 11  2  6  4 11]
# Cost =-513.0887058823529
# Current combination:
# [ 2  4  7 10  8  2  5  4 10  3  8  4 11]
# Cost =-470.2809411764706
# Current combination:
# [ 4  2 14 12  7  6  9  9  5  6  2  9  5]
# Cost =-563.2404117647059
# Current combination:
# [ 3  3  9  6  7  4  1  3 11  6  9  7  7]
# Cost =-676.866
# Current combination:
# [ 2  9 11  8  1  4  3  3  7  2  2  3 11]
# Cost =-775.3718235294118
# Current combination:
# [ 5  4 15 10  8  2  8  3  5  3  4  4  6]
# Cost =-504.8874117647059
# Current combination:
# [ 6  2 15  5  7  4  8  3 10  7  5  2  5]
# Cost =-695.2851176470588
# Current combination:
# [ 3  2  6  6  7  4  8  3  6  6  9  9 10]
# Cost =-480.03564705882354
# Current combination:
# [ 4  5  8 10  8  2  4  4 10  4  6  4 12]
# Cost =-470.8495882352941
# Current combination:
# [ 5  7 11  6  7  2  4  4  7  2  9  6  6]
# Cost =-426.6498235294118
# Current combination:
# [ 4  6 13  6  5  6 10  6  5  4  4  4  9]
# Cost =-477.95788235294117
# Current combination:
# [3 5 6 6 7 4 8 2 6 3 5 7 7]
# Cost =-525.5341176470588
# Current combination:
# [ 2  9 11  6  8  7  8  5 10  6  7  8  4]
# Cost =-496.6097647058824
# Current combination:
# [ 2  9 12 10  8  2  3  7  7  6  5 10  6]
# Cost =-545.8484117647058
# Current combination:
# [5 6 9 8 7 5 4 7 2 6 2 7 5]
# Cost =-572.3380588235294
# Current combination:
# [ 3  8 10  6  7  3  8  8 11  6  9  7  7]
# Cost =-431.161
# Current combination:
# [ 2  1 13 11  6  7  8  3  8  4  1  4 11]
# Cost =-691.2227647058824
# Current combination:
# [ 5  4  7 10  9  1  9  8  7  4  4 10  6]
# Cost =-610.2104705882354
# Current combination:
# [4 8 6 4 7 4 8 7 6 7 3 3 5]
# Cost =-505.3603529411764
# Current combination:
# [ 3  3  6  6  7  4  5  3 10  7  5  6  7]
# Cost =-437.75041176470586
# Current combination:
# [ 3  7 12 12  9  2  2  4  2  5  1  4 11]
# Cost =-615.1368235294117
# Current combination:
# [ 5  6 11 10  8  2  3  4 10  2  4  4  6]
# Cost =-484.7038823529411
# Current combination:
# [ 4  3  9  5  5  6  9  8  9  4  3 11  8]
# Cost =-431.9290588235294
# Current combination:
# [ 2  5 14  4  6  6 10 10 11  7  4  7  4]
# Cost =-533.5430588235295
# Current combination:
# [ 2  2  7  9  6  2 10  8 11  7  1  6 11]
# Cost =-675.6208823529411
# Current combination:
# [ 7  8 10  5  9  6  3 10  7  4  2  8  6]
# Cost =-493.5845294117648
# Current combination:
# [ 4  8  6  6  7  4  8  3  6  2  8  4 12]
# Cost =-418.4715294117647
# Current combination:
# [ 3  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-394.9705882352941
# Current combination:
# [ 2  2 15 12  6  2  9  7  6  5  6  4 12]
# Cost =-560.3037058823529
# Current combination:
# [ 5  4  7 12  7  6  9  9  7  4  4  4  7]
# Cost =-473.4271764705883
# Current combination:
# [ 4  8  6  6  7  4  8  3  6  2  8 11  5]
# Cost =-465.79988235294115
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  6  9  7  7]
# Cost =-415.808
# Current combination:
# [ 5  9 11  8  6  2  3  4  9  2  4  3 11]
# Cost =-549.5487058823529
# Current combination:
# [ 3  4  7 12  6  5  5  9  7  4  6  6  3]
# Cost =-563.6055294117648
# Current combination:
# [ 4  8 15  5  1  6  8  3  6  7  5  4  4]
# Cost =-840.5790588235295
# Current combination:
# [ 3  7  9  6  9  2  8  8 11  6  9  7 12]
# Cost =-435.66188235294123
# Current combination:
# [ 6  9 15 12  6  2  7  8  7  6  5  8 11]
# Cost =-500.37041176470586
# Current combination:
# [ 3  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-394.9705882352941
# Current combination:
# [ 6  7  6  6  7  4 10 11 11  6  9  7  7]
# Cost =-409.40058823529415
# Current combination:
# [ 3  8  6  6  7  4  8  3  6  2  8  4 12]
# Cost =-426.9440588235294
# Current combination:
# [ 4  8  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.68194117647056
# Current combination:
# [ 3  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-394.9705882352941
# Current combination:
# [ 6  7  6  6  7  4 10 11 11  6  9  7  7]
# Cost =-409.40058823529415
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  2  8  4 12]
# Cost =-492.62664705882355
# Current combination:
# [ 4  8  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.68194117647056
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [ 6  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-399.653294117647
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  6  9  4 12]
# Cost =-493.1274117647059
# Current combination:
# [ 4  8  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.68194117647056
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [ 6  7  8  6  7  4 10 11 11  6  9  7  7]
# Cost =-429.23947058823535
# Current combination:
# [ 3  8  6  6  7  4  8  3  6  2  8  4 12]
# Cost =-426.9440588235294
# Current combination:
# [ 4  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.5559999999999
# Current combination:
# [ 3  7  6  6  7  2  8  8 11  6  9  7  7]
# Cost =-395.10835294117646
# Current combination:
# [ 6  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-399.653294117647
# Current combination:
# [ 3  7  6  6  7  4  8  3  6  2  8  4 12]
# Cost =-423.56364705882356
# Current combination:
# [4 8 6 6 7 4 8 3 6 2 8 7 7]
# Cost =-441.2491176470589
# Current combination:
# [ 3  7  6  6  7  2  8  8 11  6  9  7  7]
# Cost =-395.10835294117646
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  6  9  7  7]
# Cost =-415.808
# Current combination:
# [ 3  7  8  6  7  4  8  3  6  2  8  4 12]
# Cost =-437.88005882352945
# Current combination:
# [ 4  8  6  6  7  4  8  3 11  4  9  7  7]
# Cost =-474.15376470588234
# Current combination:
# [ 3  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-394.9705882352941
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  6  9  7  7]
# Cost =-415.808
# Current combination:
# [ 3  7  6  6  7  4  8  3  6  2  8  4 12]
# Cost =-423.56364705882356
# Current combination:
# [ 4  8  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.68194117647056
# Current combination:
# [ 6  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-399.653294117647
# Current combination:
# [ 6  7  6  6  7  4 10 11 11  6  9  7  7]
# Cost =-409.40058823529415
# Current combination:
# [ 3  7  8  6  7  4 10  3  6  2  8  4 12]
# Cost =-447.96964705882357
# Current combination:
# [4 8 6 6 7 4 8 3 6 2 9 7 7]
# Cost =-442.96911764705885
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  6  9  7  7]
# Cost =-415.808
# Current combination:
# [ 3  7  8  6  7  4  8  3  6  2  8  4 12]
# Cost =-437.88005882352945
# Current combination:
# [ 4  8  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.68194117647056
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [ 6  7  6  6  7  5 10 11 11  6  9  7  7]
# Cost =-415.6305294117647
# Current combination:
# [ 3  7  8  6  7  4  8  3  6  2  8  4 12]
# Cost =-437.88005882352945
# Current combination:
# [4 8 6 6 7 4 8 3 6 2 8 4 7]
# Cost =-409.50864705882356
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [ 6  7  8  6  7  4 10 11 11  6  9  7  7]
# Cost =-429.23947058823535
# Current combination:
# [ 3  7  8  6  7  4 10 11 11  6  9  4 12]
# Cost =-493.1274117647059
# Current combination:
# [ 4  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.5559999999999
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [ 6  7  6  6  7  4 10 11 11  6  9  7  7]
# Cost =-409.40058823529415
# Current combination:
# [ 5  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-399.76694117647065
# Current combination:
# [ 6  7  6 12  7  4 10  4 11  6  9  7 11]
# Cost =-437.22300000000007
# Current combination:
# [ 4  4 14  6  2  7  5  2  2  3  8  8  6]
# Cost =-620.9012941176471
# Current combination:
# [ 3  8  6  6  7  2  8  4 11  4  9  5  3]
# Cost =-544.7765294117647
# Current combination:
# [ 7  4  7  8  7  2  8 11 11  4  9  9  5]
# Cost =-450.36047058823533
# Current combination:
# [ 6  7  6  6  7  4  2  2 11  6  9  7  7]
# Cost =-573.4814117647059
# Current combination:
# [ 2  8  8  4  4  4 10 11  7  3  8 11  7]
# Cost =-429.2470588235294
# Current combination:
# [ 4  8 12  6  7  2  4  6 11  4  2  7  7]
# Cost =-484.8538235294118
# Current combination:
# [ 1  7  6  8  7  4  8  8 11  6  1  7  7]
# Cost =-707.2021176470588
# Current combination:
# [ 6  7  6  6  7  5  8  8 11  7  9  7  7]
# Cost =-403.45900000000006
# Current combination:
# [ 6  6  8  6  5  3 10 11  2  6  9  6 11]
# Cost =-562.6332352941176
# Current combination:
# [ 4  8  6  6  7  7  8  7 11  7  9 11  7]
# Cost =-438.56758823529407
# Current combination:
# [ 3  7  8  6  7  5  3  8 11  6  6  7  9]
# Cost =-469.10576470588234
# Current combination:
# [ 6  3  9  4  1  4 10 11  5  4  6  9  8]
# Cost =-863.2716470588235
# Current combination:
# [ 3  1  6  6  3  4  8 10  6  4  9  8  7]
# Cost =-639.3830588235294
# Current combination:
# [ 4  7  6  6  7  2  8  9 11  4  5  7  8]
# Cost =-397.770294117647
# Current combination:
# [ 3  7  6 10  7  2  3  8 11  6  9  7  7]
# Cost =-483.93370588235297
# Current combination:
# [ 6  7  6 12  7  5  8 11 11  6  9  7  7]
# Cost =-432.5580588235294
# Current combination:
# [ 6  3 13 11  7  1  9  3  6  7  8  8  7]
# Cost =-640.1371764705883
# Current combination:
# [ 6  9  8  9  6  5  5 11  6  2  5 11  7]
# Cost =-443.5778823529412
# Current combination:
# [ 3  7  6  6  7  2  8  8 11  6  9  7 11]
# Cost =-404.055294117647
# Current combination:
# [ 6  1  8  6  9  7 10  3  7  4  3  7  7]
# Cost =-641.566705882353
# Current combination:
# [ 4  3 11  3  9  4  4  3  2  2  6  4 12]
# Cost =-581.698411764706
# Current combination:
# [ 4  8  6 12  8  5  1  5 11  4  5  9  7]
# Cost =-684.3589411764707
# Current combination:
# [ 3  7 15  6  7  2  8  2 11  4  9  7  7]
# Cost =-641.1804705882353
# Current combination:
# [ 1  9  9  4  7  4 10  3  6  1  5  7  7]
# Cost =-588.2867647058823
# Current combination:
# [6 3 8 6 8 4 2 7 9 3 6 5 6]
# Cost =-546.2424705882353
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [ 6  7  6  6  7  5  8  8 11  7  9  3  7]
# Cost =-577.4509411764706
# Current combination:
# [ 6  7  6  6  7  5  9 11  8  6  9  7  7]
# Cost =-398.08152941176473
# Current combination:
# [ 2  7  8  6  7  4  2  9  4  3  1  4 12]
# Cost =-583.9707647058824
# Current combination:
# [ 3  8  6  3  6  7  2  8  3  2  2 11 11]
# Cost =-572.1904117647059
# Current combination:
# [ 1  7  6  7  7  5  5 11 11  1  9  7 12]
# Cost =-640.1524705882352
# Current combination:
# [ 7  9  8  3  2  5 10 11 11  6  7  9  7]
# Cost =-689.094705882353
# Current combination:
# [ 3  4  8  4  3  3  6  3 11  4  5  6  9]
# Cost =-463.46764705882356
# Current combination:
# [ 4  8  6  6  7  2  8  9 11  2  9  4  7]
# Cost =-469.93129411764704
# Current combination:
# [ 5  4 12  6  7  5  8  8 11  6  9  7  7]
# Cost =-452.3588235294117
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-369.2151176470587
# Current combination:
# [7 7 8 3 7 3 4 9 6 3 6 4 4]
# Cost =-489.5819411764706
# Current combination:
# [ 4  8  6  6  3  4  8  3  6  2  8  4 11]
# Cost =-425.6610588235294
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [6 6 8 8 7 6 4 9 8 6 9 8 7]
# Cost =-418.3637647058824
# Current combination:
# [ 3  5 10  9  1  4 10  3  6  4  9  4 12]
# Cost =-817.3049999999998
# Current combination:
# [ 4  7  6  6  7  2  8  9 11  4  9  7  7]
# Cost =-395.5559999999999
# Current combination:
# [ 3  4  6  6  7  5  8  8 11  6  9  7  9]
# Cost =-386.8585882352941
# Current combination:
# [ 6  1  6  6  7  4 10 11 11  4  9  7  7]
# Cost =-687.1014117647059
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-379.4312352941176
# Current combination:
# [ 3  4  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-388.8982352941177
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [3 7 6 6 7 5 8 6 5 3 9 7 8]
# Cost =-354.7910588235294
# Current combination:
# [ 7  8  6  5  5  5  9  8 11  6  9  7  9]
# Cost =-404.6732352941176
# Current combination:
# [ 3  4  6  6  7  5  7  9 11  5  9  7  7]
# Cost =-385.93594117647064
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-369.2151176470587
# Current combination:
# [ 7  8  6  5  5  5  8  8 11  6  9  7  9]
# Cost =-391.5477058823529
# Current combination:
# [ 3  4  6  6  7  5  8  8 11  5  9  7  7]
# Cost =-386.73935294117643
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  6  9  7  7]
# Cost =-398.382
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  3  9  7  8]
# Cost =-382.639
# Current combination:
# [ 7  8  6  5  5  5  9  8 11  6  9  7  9]
# Cost =-404.6732352941176
# Current combination:
# [ 3  4  6  6  7  5  7  9 11  5  9  7  7]
# Cost =-385.93594117647064
# Current combination:
# [ 3  7  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-392.96194117647053
# Current combination:
# [3 7 6 6 7 5 9 6 5 3 9 7 8]
# Cost =-369.36699999999996
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-379.4312352941176
# Current combination:
# [ 3  4  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-388.8982352941177
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [3 7 6 6 7 5 9 6 5 3 9 7 8]
# Cost =-369.36699999999996
# Current combination:
# [ 7  8  6  5  5  5  9  8 11  6  9  7  9]
# Cost =-404.6732352941176
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [ 4  8  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-395.2936470588235
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-369.2151176470587
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-379.4312352941176
# Current combination:
# [ 3  4  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-388.8982352941177
# Current combination:
# [ 4  8  6  6  7  3  8  8 11  6  9  7  7]
# Cost =-393.2491176470588
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [ 7  8  6  5  5  5  9  6 11  6  9  7  9]
# Cost =-394.4111176470588
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [ 4  8  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-395.2936470588235
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-379.4312352941176
# Current combination:
# [ 3  4  6  6  7  5  7  9 11  5  9  7  7]
# Cost =-385.93594117647064
# Current combination:
# [ 4  8  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-395.2936470588235
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [7 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-379.4312352941176
# Current combination:
# [ 3  4  6  6  7  5  8  8 11  5  9  7  7]
# Cost =-386.73935294117643
# Current combination:
# [ 4  8  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-395.2936470588235
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 9 7 8]
# Cost =-380.0696470588235
# Current combination:
# [ 7  8  6  5  5  5  8  8 11  6  9  7  9]
# Cost =-391.5477058823529
# Current combination:
# [ 4  8  6  6  7  3  7  9 11  5  9  7  7]
# Cost =-389.88841176470584
# Current combination:
# [ 4  8  6  6  7  5  8  8 11  6  9  7  7]
# Cost =-395.2936470588235
# Current combination:
# [3 7 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-356.78923529411753
# Current combination:
# [ 7  8  6  5  7  5  8  8 11  6  9  7  9]
# Cost =-404.13882352941175
# Current combination:
# [ 3  4  6  6  7  5  8  9 11  5  9  7  7]
# Cost =-387.7577058823529
# Current combination:
# [ 6  8  6  5  9  5  9  2 11  3  9  7  9]
# Cost =-568.4091176470588
# Current combination:
# [ 1  4  6 12  7  7  8  9  6  3  9  7 10]
# Cost =-654.3443529411765
# Current combination:
# [ 6  8  6  8  2  4  7 10  4  6  9  9  5]
# Cost =-624.977294117647
# Current combination:
# [3 1 6 6 7 1 4 6 5 3 9 7 8]
# Cost =-629.5194117647059
# Current combination:
# [ 4  8 15  5  5  4  9  2  7  5  3  9  6]
# Cost =-623.0421176470588
# Current combination:
# [ 5  4 13  4  7  3  7  9  9  2  6  7  7]
# Cost =-436.27694117647053
# Current combination:
# [ 4  3 14  4  9  3  4  6  4  5  9  7  8]
# Cost =-496.3984705882353
# Current combination:
# [ 6  7 10 12  6  6  8  8 11  6  6  8  4]
# Cost =-556.5867058823529
# Current combination:
# [ 5  7  6 10  7  7  8  8 10  5  9  7  3]
# Cost =-594.5207647058824
# Current combination:
# [ 2  7 10 12  3  3  2  9  9  7  9  5 12]
# Cost =-602.6179411764706
# Current combination:
# [ 3  7 14 10  3  5  8  8  8  3  9 10  8]
# Cost =-511.40188235294124
# Current combination:
# [ 7  1  6 11  1  5  1  8 11  6  1  7  9]
# Cost =-739.938411764706
# Current combination:
# [2 4 7 9 1 1 7 2 4 4 4 7 3]
# Cost =-769.0592941176471
# Current combination:
# [ 7  8  6  6  3  5  8  8 11  5  6  9  6]
# Cost =-431.89217647058825
# Current combination:
# [3 5 6 6 7 5 9 6 2 3 9 7 8]
# Cost =-522.2431176470589
# Current combination:
# [ 7  8 15  9  5  5  9  6  9  3  9  7  9]
# Cost =-472.21041176470595
# Current combination:
# [ 4  6 12  6  9  2  7  8 11  1  9  7  7]
# Cost =-553.9257647058823
# Current combination:
# [ 4  7  8  8  7  3  7  4 10  5  2  9  7]
# Cost =-470.7494705882353
# Current combination:
# [3 3 6 6 7 4 9 3 5 3 1 9 8]
# Cost =-620.6207058823529
# Current combination:
# [ 7  7  6  8  7  2  9  8  8  6  9 11  9]
# Cost =-442.94564705882345
# Current combination:
# [ 1  3  6 11  7  5  5  9  2  1  2  6  7]
# Cost =-658.7458823529412
# Current combination:
# [ 4  8  7  6  7  5  2  8 11  6  5  7 11]
# Cost =-580.7012941176471
# Current combination:
# [7 8 6 3 5 5 3 6 5 3 1 7 8]
# Cost =-634.7068823529411
# Current combination:
# [7 8 6 5 5 5 7 6 5 3 9 7 9]
# Cost =-371.16523529411756
# Current combination:
# [ 6  5 15  6  8  3  3  4 11  5  9  8 10]
# Cost =-558.2463529411765
# Current combination:
# [ 4  8  6  6  7  4  9 10 11  1  3  7  8]
# Cost =-499.295
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [ 4  5  6  5  5  3  3  9  5  6  4 10 10]
# Cost =-463.21388235294125
# Current combination:
# [ 7  8 15  6  7  3  9  3  2  5  9  7  6]
# Cost =-648.0821176470588
# Current combination:
# [ 4  2  8  6  4  7  8  8 11  2  9  7 10]
# Cost =-472.2575294117647
# Current combination:
# [2 8 6 4 5 5 2 6 5 3 9 8 8]
# Cost =-517.886294117647
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-367.15547058823523
# Current combination:
# [ 1  6 10  5  2  3  2  9  4  6  7  8  3]
# Cost =-642.6628823529412
# Current combination:
# [4 8 6 9 7 5 5 8 8 4 9 4 6]
# Cost =-467.0935294117647
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-362.9696470588235
# Current combination:
# [ 7  8  6  4  5  5 10  9  5  3  9  9  3]
# Cost =-550.1538235294117
# Current combination:
# [ 2  2  6  3  7  5  8  6 11  1  9  3  7]
# Cost =-533.9273529411764
# Current combination:
# [ 7  8 11  8  6  5  1  8 10  5  3 10  7]
# Cost =-745.5198823529413
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 5 6 8]
# Cost =-357.88758823529406
# Current combination:
# [ 5  9 12 12  9  2  7  8  5  6  3  2  6]
# Cost =-684.7718235294118
# Current combination:
# [ 4  8  9  9  7  6  5 11  7  2  1  4 11]
# Cost =-655.194
# Current combination:
# [ 4  8  8  3  5  5  7 11 11  2  1  8  7]
# Cost =-690.3985294117647
# Current combination:
# [ 3  7 14  5  5  5  9  9  5  3  9  7  8]
# Cost =-443.7964117647059
# Current combination:
# [ 6  8  6  9  7  5  7  4  2  6  9 11  9]
# Cost =-597.9328823529412
# Current combination:
# [ 5  5 11  6  7  5  3  2  3  2  6  7  8]
# Cost =-558.7057647058823
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-346.55705882352936
# Current combination:
# [3 7 6 6 8 5 9 6 5 3 9 7 8]
# Cost =-364.7338823529411
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 5 6 8]
# Cost =-357.88758823529406
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 9 7 8]
# Cost =-380.0696470588235
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 5 5 8 8 5 3 5 6 8]
# Cost =-339.1508235294117
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-362.9696470588235
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-355.2808235294117
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-362.9696470588235
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-346.55705882352936
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 9 7 8]
# Cost =-380.0696470588235
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 6 7 5 8 8 5 3 5 6 8]
# Cost =-353.6793529411765
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 9 7 8]
# Cost =-380.0696470588235
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-367.15547058823523
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 6 8]
# Cost =-345.8572352941176
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 9 7 8]
# Cost =-380.0696470588235
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 5 6 8]
# Cost =-357.88758823529406
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-354.43623529411764
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 5 7 8]
# Cost =-364.5906470588235
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 9 7 9]
# Cost =-355.2808235294117
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 5 6 8]
# Cost =-357.88758823529406
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [3 8 6 5 8 5 9 6 5 3 9 7 9]
# Cost =-364.8013529411765
# Current combination:
# [5 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-355.44605882352937
# Current combination:
# [3 8 6 5 7 5 8 8 5 3 5 6 8]
# Cost =-357.78076470588235
# Current combination:
# [3 7 6 6 7 5 8 8 5 3 9 7 8]
# Cost =-380.0696470588235
# Current combination:
# [3 4 6 7 4 5 9 4 5 3 5 9 8]
# Cost =-369.0353529411765
# Current combination:
# [ 3  7 10  6  9  4  5 11  5  1  2  7  4]
# Cost =-507.5695294117646
# Current combination:
# [ 3  1  9  5  8  5  2 10  2  7  9 11  9]
# Cost =-705.2027647058824
# Current combination:
# [5 8 6 5 2 5 9 6 5 3 9 7 8]
# Cost =-571.6300000000001
# Current combination:
# [3 7 6 6 7 2 8 8 5 3 5 6 8]
# Cost =-354.23952941176464
# Current combination:
# [ 3  7  6  6  7  5  9 11  9  1  3  6  4]
# Cost =-491.75211764705875
# Current combination:
# [2 9 6 5 8 3 9 2 8 1 1 4 9]
# Cost =-549.2430588235293
# Current combination:
# [ 5  8  6  5  5  2  9  6 11  4  9  7  8]
# Cost =-387.7580588235294
# Current combination:
# [ 3  8  6 10  5  5  8  8  5  3  5  6  4]
# Cost =-406.05811764705885
# Current combination:
# [ 3  1  6 11  1  5  1  5  5  4  9  7  8]
# Cost =-701.8472352941176
# Current combination:
# [3 8 6 5 5 3 9 7 5 3 9 6 9]
# Cost =-365.2612352941176
# Current combination:
# [5 8 6 5 5 5 9 6 5 6 9 7 8]
# Cost =-379.54423529411764
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 9 7 8]
# Cost =-366.3638235294118
# Current combination:
# [3 5 6 7 6 5 6 7 2 7 9 7 7]
# Cost =-533.484588235294
# Current combination:
# [3 8 6 7 3 5 2 7 5 4 7 7 7]
# Cost =-535.8689411764706
# Current combination:
# [5 4 6 5 5 1 9 6 5 3 3 7 7]
# Cost =-515.4828823529411
# Current combination:
# [3 8 6 5 1 1 9 6 5 2 2 7 8]
# Cost =-770.2625294117647
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 5 8]
# Cost =-364.98811764705886
# Current combination:
# [ 3  3 15 12  8  4 10  2  7  3  9  3  9]
# Cost =-612.8440588235294
# Current combination:
# [ 5  8  6  5  5  5  9  6  5  3  9  7 10]
# Cost =-368.66282352941175
# Current combination:
# [5 8 6 5 1 5 9 6 5 3 5 6 8]
# Cost =-785.1974117647057
# Current combination:
# [ 3  3  6 12  7  5  2  5 10  2  9  2  5]
# Cost =-589.5324117647059
# Current combination:
# [ 2  5 14  5  5  4  9  7  5  2  8  2 11]
# Cost =-683.6135882352941
# Current combination:
# [ 5  8 14  5  5  5  9  2  5  3  9  7  4]
# Cost =-589.5506470588236
# Current combination:
# [ 3  8  6 11  7  5  8  8  5  3  5  6  8]
# Cost =-386.3318235294118
# Current combination:
# [ 6  5  6  6  7  6  4  7  5  4  9 10 10]
# Cost =-401.9365882352941
# Current combination:
# [ 7  5 12  5  2  1  9  6  5  3  4  8  9]
# Cost =-640.633
# Current combination:
# [5 8 6 5 5 5 9 6 9 4 9 7 8]
# Cost =-369.18305882352934
# Current combination:
# [ 3  1  6  5  6  3  9  6 10  6  9  6  3]
# Cost =-638.1972352941176
# Current combination:
# [7 4 6 5 6 5 6 8 5 6 5 5 8]
# Cost =-378.0777647058823
# Current combination:
# [ 6  1  6  5  5  5  6  6 10  7  5 10 12]
# Cost =-685.7395294117647
# Current combination:
# [ 5  8 11  5  5  5  9  6  6  3  9  7  8]
# Cost =-399.90805882352936
# Current combination:
# [ 3  7 11  9  7  5  8  8  5  3  5 11  8]
# Cost =-456.53111764705875
# Current combination:
# [ 3  2 14  5  8  5  9  6  4  3  9  7  8]
# Cost =-526.7545294117647
# Current combination:
# [ 7  6 15  5  7  5  3  7  5  2  8  2  9]
# Cost =-662.5380588235294
# Current combination:
# [ 5  8  6  5  5  5  9  6 11  3  9  4  8]
# Cost =-464.17494117647055
# Current combination:
# [ 3  8  8  5  5  5  1 10  5  3  9  7  8]
# Cost =-640.9935294117647
# Current combination:
# [ 5  8  9  9  3  5  6  9 11  3  1 11 11]
# Cost =-739.2602352941177
# Current combination:
# [3 8 6 5 9 2 9 6 5 2 7 7 9]
# Cost =-361.43952941176474
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-353.3978823529411
# Current combination:
# [ 3  7 12  8  3  5  8  8  5  3  5  6  8]
# Cost =-435.0632352941177
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [ 5  1  6  5  5  6  9 10  5  5  3  6  7]
# Cost =-620.3745294117646
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [ 4  2 15 10  7  7  8  8  5  3  5  6  8]
# Cost =-535.7325294117647
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 6 7 8]
# Cost =-363.20864705882343
# Current combination:
# [2 8 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-374.9791176470588
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 8 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-350.10894117647064
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 6 7 8]
# Cost =-363.20864705882343
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-353.3978823529411
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-346.55705882352936
# Current combination:
# [3 6 6 5 8 5 9 6 5 3 6 7 8]
# Cost =-350.598
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-353.3978823529411
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 8 8 5 3 5 6 8]
# Cost =-339.1508235294117
# Current combination:
# [3 6 6 5 8 5 9 6 5 3 6 7 8]
# Cost =-350.598
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-366.1488235294117
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 8 6 5 5 5 9 8 5 3 5 6 8]
# Cost =-346.7788823529412
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-353.3978823529411
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [3 6 6 5 8 5 9 6 5 3 6 7 8]
# Cost =-350.598
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [3 6 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-360.94335294117644
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-366.1488235294117
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 6 8]
# Cost =-342.72323529411767
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-366.1488235294117
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [3 8 6 5 5 5 8 8 5 3 5 6 8]
# Cost =-339.1508235294117
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-358.7168235294117
# Current combination:
# [3 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-353.5477058823529
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-346.55705882352936
# Current combination:
# [3 6 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-360.94335294117644
# Current combination:
# [2 7 6 5 8 5 9 6 5 3 9 7 8]
# Cost =-376.41229411764704
# Current combination:
# [3 7 6 5 8 5 9 6 5 4 4 7 8]
# Cost =-359.15617647058826
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 6 6 5 8 5 9 6 5 3 6 7 8]
# Cost =-350.598
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 9 7 8]
# Cost =-366.1488235294117
# Current combination:
# [3 7 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-353.5820588235294
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 5 6 8]
# Cost =-352.8265294117647
# Current combination:
# [3 6 6 5 8 5 8 8 5 3 6 7 8]
# Cost =-363.20864705882343
# Current combination:
# [3 6 6 6 8 5 9 8 5 3 5 6 8]
# Cost =-356.99911764705877
# Current combination:
# [ 2  4  6  5  1  3  7  3 11  5  4  7  9]
# Cost =-803.2260588235295
# Current combination:
# [ 3  8  7 11  7  7  9  7  3  3  4  5  8]
# Cost =-482.77023529411764
# Current combination:
# [ 4  2 15  4  8  5  4 10  2  4  4  6  3]
# Cost =-616.5676470588235
# Current combination:
# [3 8 6 5 6 6 8 8 6 3 5 3 8]
# Cost =-487.7405882352941
# Current combination:
# [ 3  6 14 10  8  6  5  8  9  3  5  6  6]
# Cost =-450.85752941176474
# Current combination:
# [2 8 6 5 5 3 2 8 5 3 6 7 8]
# Cost =-519.1308235294117
# Current combination:
# [ 5  7 11  5  7  5  1 11  5  4  4  5  3]
# Cost =-649.0368823529412
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-346.55705882352936
# Current combination:
# [ 3  6  6 10  1  5  9  6 10  2  6  7  8]
# Cost =-827.1415294117646
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-341.8400588235294
# Current combination:
# [ 3  8  6  6  5  5  9  6  5  4  4  7 12]
# Cost =-350.8018235294117
# Current combination:
# [ 3  8  6  5  5  5  7  8 10  3  5  6  8]
# Cost =-364.90305882352936
# Current combination:
# [3 6 6 5 8 5 9 6 5 3 6 7 8]
# Cost =-350.598
# Current combination:
# [ 2  8 11  4  3  2  8 10  8  4  1  7  8]
# Cost =-681.5133529411764
# Current combination:
# [4 7 7 5 4 7 9 6 5 4 8 7 8]
# Cost =-366.234
# Current combination:
# [ 3  8 12  5  5  5  9  8  5  3  7  4  8]
# Cost =-471.33717647058825
# Current combination:
# [ 1  6  6  5  8  7 10  8  5  3  9  6  8]
# Cost =-618.8801764705883
# Current combination:
# [ 2  8  6  5  9  5  9 10  5  3  6  7  7]
# Cost =-372.79847058823526
# Current combination:
# [4 7 6 9 8 7 9 7 5 4 9 6 8]
# Cost =-374.80829411764705
# Current combination:
# [ 3  6 15  5  8  2 10  8  5  3  5  8  3]
# Cost =-595.4556470588236
# Current combination:
# [ 3  2  6 11  5  5  5  6  5  3  6  7  8]
# Cost =-439.926
# Current combination:
# [ 3  7  6  5  8  5  9 10  5  5  2  7  8]
# Cost =-408.8341764705882
# Current combination:
# [3 6 6 4 6 4 7 9 5 7 6 7 8]
# Cost =-369.1318823529411
# Current combination:
# [ 3  6  6  5  8  5  3  8  5  3  5  6 11]
# Cost =-418.749294117647
# Current combination:
# [5 6 9 6 5 4 9 6 5 4 3 7 7]
# Cost =-385.571294117647
# Current combination:
# [ 2  7 15  5  7  5  1  6  5  3  2  5  5]
# Cost =-669.2156470588235
# Current combination:
# [ 3  1 12  5  5  5 10  6  5  4  4  9  6]
# Cost =-715.0257058823529
# Current combination:
# [3 8 6 3 5 5 9 6 2 4 4 6 8]
# Cost =-535.1161176470588
# Current combination:
# [3 6 6 4 8 5 8 8 5 3 5 4 8]
# Cost =-429.1353529411765
# Current combination:
# [ 7  8 11  5  6  5  1  6  2  6  4  7  8]
# Cost =-639.7338235294117
# Current combination:
# [3 8 6 5 5 5 8 9 5 3 5 6 8]
# Cost =-353.8134705882352
# Current combination:
# [ 3  8  7 12  1  5  9  6  4  6  1  7  4]
# Cost =-804.3341764705882
# Current combination:
# [ 3  7 12  5  8  2  9  6  5  5  9  7  8]
# Cost =-427.9631764705882
# Current combination:
# [3 7 6 8 8 6 3 6 5 3 9 9 7]
# Cost =-442.9934117647059
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 6 6 3 7 4 9 6 8 3 4 7 8]
# Cost =-450.3545294117647
# Current combination:
# [ 2  7 15  5  8  5  7  6  6  3  6 10  5]
# Cost =-471.4044117647059
# Current combination:
# [ 3  9  6 11  2  5 10  6  5  4  6  9  3]
# Cost =-621.2861176470589
# Current combination:
# [ 3  8 14  5  5  7  9  7  6  4  2  2  6]
# Cost =-657.6125882352941
# Current combination:
# [ 3  6  6  5  8  5  5  6  5  2  6  7 10]
# Cost =-352.0406470588235
# Current combination:
# [ 5  7  9  5  9  5  4  3  5  6  7 11  4]
# Cost =-498.54158823529406
# Current combination:
# [ 3  7  6 12  5  5  9  6  5  4  4  7  8]
# Cost =-379.2755882352941
# Current combination:
# [ 2  9  6 12  8  3  8  8  9  3  5  6  9]
# Cost =-400.919
# Current combination:
# [ 7  2 13  8  8  1  8  8  6  3  7 10  8]
# Cost =-659.3414705882353
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 4 7 8]
# Cost =-355.8105882352941
# Current combination:
# [ 3  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-349.4967058823529
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [ 3  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-349.4967058823529
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-358.7168235294117
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-346.55705882352936
# Current combination:
# [3 8 6 5 5 5 9 6 5 3 6 7 8]
# Cost =-358.7168235294117
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-341.8400588235294
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 6 7 8]
# Cost =-363.505
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [ 3  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-349.4967058823529
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [3 8 6 5 5 5 9 6 5 4 4 7 8]
# Cost =-348.5054705882353
# Current combination:
# [ 3  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-349.4967058823529
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 6 8]
# Cost =-345.55005882352935
# Current combination:
# [2 8 6 5 5 5 9 2 5 3 5 6 8]
# Cost =-512.4928823529411
# Current combination:
# [ 3  8 10  5  5  2  9  4  5  3  5  6  8]
# Cost =-392.4251176470588
# Current combination:
# [ 3  8 14  7  5  3  5  6  2  4  5  7  4]
# Cost =-597.3920588235294
# Current combination:
# [ 3  3  9 12  5  6 10  6  5  2  9  7  8]
# Cost =-416.949
# Current combination:
# [2 8 6 5 5 4 9 7 8 3 5 6 8]
# Cost =-351.43417647058817
# Current combination:
# [2 8 6 5 5 5 8 6 5 3 8 6 8]
# Cost =-350.250294117647
# Current combination:
# [ 2  2 13  5  1  3  5 10  5  1  4  5  4]
# Cost =-772.067
# Current combination:
# [ 1  9  6  3  5  5 10  6  3  4  9  7  4]
# Cost =-591.5861176470588
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [7 8 6 5 5 5 9 6 5 5 5 6 8]
# Cost =-366.3302352941176
# Current combination:
# [ 3  5  7 10  5  1  9  7  2  5  4  7  8]
# Cost =-601.1761176470588
# Current combination:
# [4 3 6 3 5 3 2 6 4 6 4 9 6]
# Cost =-529.7468235294117
# Current combination:
# [2 8 6 5 5 3 2 6 8 3 5 6 8]
# Cost =-515.0919411764705
# Current combination:
# [2 8 6 5 5 5 9 6 5 3 5 7 4]
# Cost =-423.2873529411764
# Current combination:
# [3 8 6 5 5 3 6 6 5 5 6 8 6]
# Cost =-369.86423529411763
# Current combination:
# [ 1  2 13  5  2  3  3  5 10  4  8  5  9]
# Cost =-663.77
# Current combination:
# [ 2  8  6  5  3  3 10  6  5  3  5  6  8]
# Cost =-364.0372352941176
# Current combination:
# [ 7  8  6 10  5  3 10  9  5  3  9  6  8]
# Cost =-382.83764705882356
# Current combination:
# [ 7  8  6  6  5  5  5  7 10  4  4  8  8]
# Cost =-383.44488235294114
# Current combination:
# [ 5  8  6  8  9  2  4 10  5  3  6  3  9]
# Cost =-536.123588235294
# Current combination:
# [2 8 6 7 5 3 6 6 5 3 4 6 8]
# Cost =-360.2174705882353
# Current combination:
# [ 6  8  6  5  5  7  9  6  5  3  5  6 11]
# Cost =-350.9260588235294
# Current combination:
# [ 3  9 13  5  8  7 10 10  5  1  4 11  8]
# Cost =-556.8299411764706
# Current combination:
# [ 3  2 15  5  5  7  7  7  8  6  8 11  7]
# Cost =-563.2831176470587
# Current combination:
# [ 2  2  6  5  6  5  9  6  5  5  3 11  8]
# Cost =-458.9733529411764
# Current combination:
# [ 2  8 13  5  5  5  3  2  5  3  5  6  4]
# Cost =-549.3404705882353
# Current combination:
# [ 2  7  6 12  5  5  9  6 10  3  1  8  8]
# Cost =-692.9666470588236
# Current combination:
# [2 8 6 5 5 3 3 9 6 3 6 7 8]
# Cost =-409.3173529411764
# Current combination:
# [ 2  8  6  5  5  5  9  6  5  3  9  6 10]
# Cost =-363.5673529411764
# Current combination:
# [ 3  8  8  5  7  5  9  6 10  2  4  8  5]
# Cost =-393.84623529411766
# Current combination:
# [ 5  2  6 11  4  3  9  6  4  7  6  9  6]
# Cost =-485.59652941176466
# Current combination:
# [2 8 6 5 5 6 5 6 5 6 5 8 8]
# Cost =-354.7645882352941
# Current combination:
# [2 6 6 5 5 5 9 6 5 3 2 6 8]
# Cost =-370.77041176470584
# Current combination:
# [ 5  8  6  5  7  5  7 11  2  2  8  7  6]
# Cost =-535.3522352941177
# ...
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  6  7  8]
# Cost =-341.8400588235294
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 6  4 10  5  5  5 10  6  5  3  3  6  7]
# Cost =-396.02976470588237
# Current combination:
# [ 5  5  6  5  5  6 10  6  5  3  5  6  8]
# Cost =-346.4476470588235
# Current combination:
# [ 2  2  6  8  5  6 10 11 11  4  7  7  8]
# Cost =-466.5275294117647
# Current combination:
# [2 9 6 5 5 3 7 6 8 3 5 6 8]
# Cost =-347.8497058823529
# Current combination:
# [ 4  4 13  9  2  5  6  6  9  4  1  6  7]
# Cost =-717.5085882352942
# Current combination:
# [ 4  5  6  5  5  3 10  6  5  5  5  6  8]
# Cost =-353.4058823529412
# Current combination:
# [ 2  9 13  5  6  4 10  6  3  2  1  7 11]
# Cost =-612.5387058823529
# Current combination:
# [ 2  4  7  8  5  3 10  6  5  3  5  6  8]
# Cost =-372.4025294117647
# Current combination:
# [ 2  3  6  5  9  3  7  4  5  3  4  6 10]
# Cost =-355.61970588235295
# Current combination:
# [ 5  5  6  5  5  3  3  6  5  3  5 11  8]
# Cost =-450.2974117647059
# Current combination:
# [ 4  1  6  4  3  6 10  6  5  2  6  3  8]
# Cost =-564.3069999999999
# Current combination:
# [ 1  8  6  3  5  4 10  6  5  3  5  3 10]
# Cost =-578.0341764705881
# Current combination:
# [ 2  3 14 11  9  4  8  9 11  7  9 11  4]
# Cost =-596.1480588235293
# Current combination:
# [ 2  5 13  5  5  3 10  6  5  3  5  6  8]
# Cost =-411.295294117647
# Current combination:
# [ 2  5  6  4  9  1 10  6  7  3  7  7  3]
# Cost =-565.1796470588235
# Current combination:
# [ 5  5 12  4  9  3  4  7  7  3  7  6 11]
# Cost =-432.2777647058823
# Current combination:
# [ 6  3  6  5  5  2 10  6  5  2  5  6  8]
# Cost =-350.40994117647057
# Current combination:
# [2 8 6 4 8 3 5 2 5 6 9 7 9]
# Cost =-528.0599411764705
# Current combination:
# [ 3  6  6  3  5  3 10  4  5  3  5  6  8]
# Cost =-423.44199999999995
# Current combination:
# [ 2  9 13 12  2  3  5  9  4  2  1  6  7]
# Cost =-714.078
# Current combination:
# [2 2 6 6 5 3 2 6 5 3 5 3 8]
# Cost =-490.621
# Current combination:
# [ 5  8  6 12  9  1  9  2  5  7  6 11  6]
# Cost =-631.4471176470588
# Current combination:
# [ 2  8  6  5  5  3 10  6 10  3  5  2  8]
# Cost =-617.1865294117647
# Current combination:
# [ 3  7  8  6  5  6  4 10 11  3  7 10 10]
# Cost =-431.6538823529412
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  1  6  8]
# Cost =-589.5096470588235
# Current combination:
# [ 2  8  6  5  1  3 10  6  5  3  9 10  8]
# Cost =-799.5712941176471
# Current combination:
# [ 2  4 11  3  5  3 10  6  8  3  5  6  9]
# Cost =-470.7145882352941
# Current combination:
# [ 2  4  6  6  5  3  4  6  5  1  7 10 12]
# Cost =-470.53088235294115
# Current combination:
# [ 2  7  6  5  5  3 10  6  5  3  5  6  5]
# Cost =-358.7452352941176
# Current combination:
# [ 7  5 11  9  5  2  9  6 10  5  6  7  7]
# Cost =-443.96270588235296
# Current combination:
# [ 2  4  6  5  9  3 10  6  5  3  5  6  8]
# Cost =-352.8641764705882
# Current combination:
# [ 3  4  6  5  7  3 10 10  8  3  4  6 10]
# Cost =-359.9305294117647
# Current combination:
# [ 2  5  6  5  1  3 10  6  5  3  4  6  8]
# Cost =-750.9397058823529
# Current combination:
# [ 1  8  9  5  4  5 10  8  5  3  6 11  8]
# Cost =-655.1478823529412
# Current combination:
# [ 2  8 14  5  5  2 10  4  5  3  5  6  8]
# Cost =-448.6797647058823
# Current combination:
# [ 7  1  7  8  5  6  9  7  4  3  5 10  5]
# Cost =-667.5139411764706
# Current combination:
# [ 7  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-353.81982352941174
# Current combination:
# [ 4  4  9  5  7  6  2 11  5  6  6  2 12]
# Cost =-606.4423529411764
# Current combination:
# [ 2  8  6  5  5  6 10  6  5  3  8  6  8]
# Cost =-350.20788235294117
# Current combination:
# [ 3  1  6  8  5  3  3  6  9  1  5  6 11]
# Cost =-623.083294117647
# Current combination:
# [ 2  8  6  5  5  3 10  3  5  3  5  6  8]
# Cost =-414.07876470588235
# Current combination:
# [2 8 6 7 5 4 4 6 5 7 6 4 8]
# Cost =-417.12329411764705
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  8  8]
# Cost =-374.904294117647
# Current combination:
# [ 7  4 13 12  5  5  9  3  8  2  5  4  7]
# Cost =-502.55870588235297
# Current combination:
# [ 2  8  6  5  9  2 10  6  5  3  5  6  8]
# Cost =-368.7459411764705
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-336.4727058823529
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-340.43411764705877
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 3  4  6  9  8  3  6  3 11  5  5  7  8]
# Cost =-461.88941176470587
# Current combination:
# [4 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-337.11423529411763
# Current combination:
# [ 2  4  6 12  5  3 10  6  5  3  5  6  8]
# Cost =-370.33876470588234
# Current combination:
# [ 4  8 11  5  5  3 10  6  5  6  1  6  8]
# Cost =-647.2222941176472
# Current combination:
# [ 2  9  6  8  5  3  9  5  7  3  9  5 10]
# Cost =-367.95082352941176
# Current combination:
# [ 2  5 14  5  5  3 10  2  5  3  5  6  9]
# Cost =-573.957
# Current combination:
# [ 2  3 12  5  6  6 10  6  5  4  5  6  8]
# Cost =-400.3001176470588
# Current combination:
# [ 2  8 15 12  5  3 10  6 11  3  5  6  8]
# Cost =-486.5486470588235
# Current combination:
# [ 4  4  8  8  5  1 10  5  5  3  7 11  7]
# Cost =-595.2145882352941
# Current combination:
# [ 2  8 15  5  4  3 10  6  5  3  9  6  8]
# Cost =-447.85341176470587
# Current combination:
# [ 2  8  6  6  5  3 10  6 10  3  2  7  8]
# Cost =-411.350588235294
# Current combination:
# [ 6  8  6  5  7  3  6 11 10  7  5  9  8]
# Cost =-417.45176470588234
# Current combination:
# [ 2  5 12  9  5  5  6  6 11  3  2 10  7]
# Cost =-524.1885294117646
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  7  6  8]
# Cost =-360.0907058823529
# Current combination:
# [ 2  8  6  5  5  3 10  9  5  4  5  6  8]
# Cost =-356.52529411764704
# Current combination:
# [1 8 6 5 5 3 5 6 5 3 8 6 8]
# Cost =-589.0032941176471
# Current combination:
# [ 5  8 11  9  2  3  3  2 10  1  6  6  5]
# Cost =-627.6196470588235
# Current combination:
# [ 5  5  6  5  5  3 10  6  9  2  4  6  8]
# Cost =-355.48970588235295
# Current combination:
# [ 5  8  6  5  5  3 10  6 10  3  5  6  8]
# Cost =-367.7006470588235
# Current combination:
# [ 2  8  6  5  5  2 10  6  5  3  5  6  8]
# Cost =-351.9250588235294
# Current combination:
# [ 6  4 12  3  2  3  3 11  5  3  5  5  4]
# Cost =-565.7730588235294
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  3  5  6  4]
# Cost =-400.4791176470588
# Current combination:
# [ 2  8  6  5  1  3 10  8  5  6  2  6  8]
# Cost =-778.6111764705882
# Current combination:
# [ 2  8  9 11  9  7  8  6  8  3  9  9  7]
# Cost =-440.8024705882352
# Current combination:
# [2 5 6 5 5 6 8 6 5 3 2 9 8]
# Cost =-405.9681764705882
# Current combination:
# [2 8 6 5 6 1 8 6 3 3 5 6 8]
# Cost =-521.8957647058824
# Current combination:
# [7 8 6 5 5 3 5 6 5 3 5 6 9]
# Cost =-356.5409411764706
# Current combination:
# [ 1  9 10  5  5  4 10  3 10  2  5  6  8]
# Cost =-629.8365294117648
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [ 2  8  6  5  5  4 10 10  5  3  5  6 12]
# Cost =-367.85441176470584
# Current combination:
# [ 2  8  6  5  5  2 10  5  5  2  5  3  8]
# Cost =-491.5605294117647
# Current combination:
# [ 6  8  6  5  6  1 10 11  5  3  5  6  7]
# Cost =-558.6865294117647
# Current combination:
# [ 2  9 12  6  5  3 10  6  5  3  5  6  8]
# Cost =-409.68247058823533
# Current combination:
# [ 7  6  7  5  5  2 10  6  5  3  5 11  8]
# Cost =-432.0807058823529
# Current combination:
# [ 2  4 14 10  2  4 10  9  4  3  3  2  4]
# Cost =-685.5404117647059
# Current combination:
# [ 2  5  9  5  5  3  2  6  5  3  5  3 11]
# Cost =-515.5209411764705
# Current combination:
# [ 6  8  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-353.5214705882353
# Current combination:
# [ 2  9  6  5  5  3 10  3  5  3  1  6  8]
# Cost =-565.2120588235293
# Current combination:
# [ 2  5 14  3  3  4  2  6  4  6  4  6 11]
# Cost =-606.2049411764706
# Current combination:
# [ 2  5  6  5  7  3 10  6 10  3  5  9  8]
# Cost =-386.84935294117645
# Current combination:
# [ 1  8  6  5  5  1 10  6  5  3  5  6  8]
# Cost =-616.5638235294118
# Current combination:
# [ 2  8  6  5  5  3 10  6  5  6  9  6  8]
# Cost =-350.79482352941176
# Current combination:
# [7 9 6 5 6 3 1 6 8 3 7 6 5]
# Cost =-625.3694705882352
# Current combination:
# [ 2  5  6  5  4  3 10  3  5  3  7  6  8]
# Cost =-403.2558235294117
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [4 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-337.11423529411763
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [2 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-327.7268235294117
# Current combination:
# [ 4  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-344.9868235294117
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-336.4727058823529
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [4 5 6 5 5 3 8 6 5 3 5 6 8]
# Cost =-333.3245294117647
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [2 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-327.7268235294117
# Current combination:
# [ 4  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-344.9868235294117
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [2 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-327.7268235294117
# Current combination:
# [4 5 6 5 5 3 8 6 5 3 5 6 8]
# Cost =-333.3245294117647
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  2  5  6  8]
# Cost =-338.54611764705874
# Current combination:
# [4 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-337.11423529411763
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [2 5 6 5 5 4 8 6 5 2 5 6 8]
# Cost =-346.44217647058827
# Current combination:
# [4 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-337.11423529411763
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-336.4727058823529
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [2 5 6 5 5 3 8 6 5 2 5 6 8]
# Cost =-327.7268235294117
# Current combination:
# [ 4  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-344.9868235294117
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [ 4  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-344.9868235294117
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  3  5  6  8]
# Cost =-336.4981176470588
# Current combination:
# [4 5 6 5 5 3 8 6 5 3 5 6 8]
# Cost =-333.3245294117647
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
# Cost =-347.2281176470588
# Current combination:
# [ 2  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-339.7522352941176
# Current combination:
# [ 2  5  6  5  5  4 10  6  5  2  5  6  8]
# Cost =-338.54611764705874
# Current combination:
# [ 4  5  6  5  5  3 10  6  5  3  5  6  8]
# Cost =-344.9868235294117
# Current combination:
# [ 2  4  6  5  5  3 10  6  5  3  5  6  7]
